# %% [markdown]
# # Predict logP
#
# The aim of this exercise is to compare model performance between a GNN and a supervised method to predict logP.
# Consider as a starting point one of the GNNs from session 14 (GCN, GIN, or GAT), and a supervised model of your choice (e.g., Random Forest with MACCS fingerprints).
#
# #### Tasks:
# 1) Create a training and a test set
# 2) Build a supervised model of your choice on the training data and evaluate its performance on the test set
# 3) Build a GNN and compare its performance to the supervised model
# 4) Discuss the outcome

# %%
# complete imports if needed for your solution
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from rdkit.Chem import RDKFingerprint
from rdkit.Chem.Descriptors import CalcMolDescriptors

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, root_mean_squared_error
from sklearn.preprocessing import StandardScaler

from rdkit import Chem

import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch_geometric.nn import GCNConv, GINConv, GATConv
from torch_geometric.loader import DataLoader
from torch_geometric.nn import global_mean_pool
from torch_geometric.data import Data

# %% [markdown]
# Load the data from Session 11

# %%
df = pd.read_csv(os.path.join("..","..", "..", "lectures", "session11", "material", "esol_modified.csv")).dropna(subset=["SMILES"])
df = df.loc[df.SMILES != 'C'] # remove the one compound containing only a single atom
df.head()
# Out:
#                                               SMILES  LogS    MolWt     LogP  \
# 0  OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)... -0.77  457.432 -3.10802
# 1                             Cc1occc1C(=O)Nc2ccccc2 -3.30  201.225  2.84032
# 2                               CC(C)=CCCC(C)=CC(=O) -2.06  152.237  2.87800
# 3                 c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43 -7.87  278.354  6.29940
# 4                                            c1ccsc1 -1.33   84.143  1.74810
#
#    EState_VSA5    TPSA  NumHAcc  NumAromaticRings  HeavyAtomCount  RingCount  \
# 0     0.000000  202.32     12.0               1.0            32.0        3.0
# 1     6.263163   42.24      2.0               2.0            15.0        2.0
# 2     5.573105   17.07      1.0               0.0            11.0        0.0
# 3    43.089794    0.00      0.0               5.0            22.0        5.0
# 4     0.000000    0.00      1.0               1.0             5.0        1.0
#
#         qed  NumHDonors  NOCount
# 0  0.217518         7.0     12.0
# 1  0.811283         1.0      3.0
# 2  0.343706         0.0      1.0
# 3  0.291526         0.0      0.0
# 4  0.448927         0.0      0.0

# %% [markdown]
# ### Setting the stage
# Split the data into training and test sets. The test set will be used to compare model performance.

# %%
# only split the dataframe indices
idx_train, idx_test = train_test_split(
    df.index, test_size=0.2, random_state=42
)

df_train = df.loc[idx_train].copy()
df_test = df.loc[idx_test].copy()

# %% [markdown]
# ### Baseline supervised model
# Choose a
#    - regression model (RF, SVR, kNN, Gradient Boost, ...)
#    - molecular descriptor (RDKit, Mordred, ...) or fingerprint (MACCS, Morgan, RDKit, ...)
#
# Build a feature matrix and target vector. Add scaling if needed for your model.
# Train the model on the training set and apply it to the test set.
# Calculate performance metrics (R2, RMSE) for model performance on the test set.

# %%
# use RDKit fingerprints
def RDKit_fp_from_smiles(smiles_list):
    fps = []
    for i, smi in enumerate(smiles_list):
        mol = Chem.MolFromSmiles(smi)
        if mol is None:
            continue
        fp = RDKFingerprint(mol)
        fps.append(np.array(fp))
    return np.array(fps)

# train model
smiles_train = df_train['SMILES'].values # Structures (SMILES)
y_train = df_train['LogP'].values # Target variable
X_train = RDKit_fp_from_smiles(smiles_train) # Calculate fingerprints (RDKit FP)
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)

# predict logP for test set
smiles_test= df_test['SMILES'].values # Structures (SMILES)
X_test = RDKit_fp_from_smiles(smiles_test) # Calculate fingerprints (RDKit FP)
y_test = df_test['LogP'].values # Target variable
y_pred = model.predict(X_test)

# look at performance
print("Reference performance: Supervised model")
print('Test R²:', r2_score(y_test, y_pred))
print('Test RMSE:', root_mean_squared_error(y_test, y_pred))
plt.figure(figsize=(5, 4))
sns.set_style('white')
performance = pd.DataFrame({'Predicted': y_pred, 'True': y_test})
sns.scatterplot(performance, x='True', y='Predicted')
plt.show()
# Out:
# Reference performance: Supervised model
# Test R²: 0.7703653200775178
# Test RMSE: 0.9113552811814216

# %%
# use RDKit descriptors
def RDKit_desc_from_smiles(smiles_list):
    descs = []
    for i, smi in enumerate(smiles_list):
        mol = Chem.MolFromSmiles(smi)
        if mol is None:
            continue
        desc = CalcMolDescriptors(mol)
        descs.append(desc)
    return pd.DataFrame(descs)

# train model
X_train = RDKit_desc_from_smiles(smiles_train) # Calculate RDKit descriptors
scaler = StandardScaler()
X_train_standard = scaler.fit_transform(X_train)

model = RandomForestRegressor(random_state=42)
model.fit(X_train_standard, y_train)

# predict logP for test set
X_test = RDKit_desc_from_smiles(smiles_test) # Calculate RDKit descriptors
X_test_standard = scaler.transform(X_test)
y_pred = model.predict(X_test_standard)

# look at performance
print("Reference performance: Supervised model")
print('Test R²:', r2_score(y_test, y_pred))
print('Test RMSE:', root_mean_squared_error(y_test, y_pred))
plt.figure(figsize=(5, 4))
sns.set_style('white')
performance = pd.DataFrame({'Predicted': y_pred, 'True': y_test})
sns.scatterplot(performance, x='True', y='Predicted')
plt.show()
# Out:
# Reference performance: Supervised model
# Test R²: 0.986522576785079
# Test RMSE: 0.22078644631560893

# %% [markdown]
# ### Unpervised GNN model
# Choose a GNN architecture
#    - GCN, GIN, or GAT
#
# Transform input smiles to graph objects using the atom and bond features. Build graphs for both training and test set. Train the GNN on the training set. Adapt architecture and parameters until you are happy with the performance. Apply the trained model on the test set (once!) and calculate model performance metrics

# %%
# same functions as in exercises
def atom_features(atom): # Create a tensor for atom features, length = 5
    return torch.tensor([
        atom.GetAtomicNum(),
        atom.GetTotalDegree(),
        atom.GetFormalCharge(),
        int(atom.GetIsAromatic()),
        atom.GetTotalNumHs(),
    ], dtype=torch.float)

def bond_features(bond): # Create a tensor for bond features, length = 6
    bt = bond.GetBondType()
    return torch.tensor([
        bt == Chem.rdchem.BondType.SINGLE,
        bt == Chem.rdchem.BondType.DOUBLE,
        bt == Chem.rdchem.BondType.TRIPLE,
        bt == Chem.rdchem.BondType.AROMATIC,
        bond.GetIsConjugated(),
        bond.IsInRing(),
    ], dtype=torch.float)

def smiles_to_graph(smiles, y):
    mol = Chem.MolFromSmiles(smiles) # Create a RDKit mol object from the smiles

    # Calculate atom features for all atoms in the molecule
    x = torch.stack([atom_features(atom) for atom in mol.GetAtoms()], dim=0)

    # Edges
    edge_index = []
    edge_attr = []
    
    # Iterate through all bonds in the molecule
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()

        # Represent molecule as an undirected graph --> add both directions
        edge_index.append([i, j]) # left to right
        edge_index.append([j, i]) # right to left

        bf = bond_features(bond) # calculate bond features 
        edge_attr.append(bf)
        edge_attr.append(bf) # add two times, once for forward and once for backwards edge

    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous() 
    edge_attr  = torch.stack(edge_attr, dim=0)

    # Target property: logP
    y = torch.tensor([y], dtype=torch.float)
    
    # x: atom stack, y: logP
    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)

# %% [markdown]
# Calculate graphs for train and test smiles

# %%
graphs_training = [smiles_to_graph(row.SMILES, row.LogP) for _, row in df_train.iterrows()]
graphs_test = [smiles_to_graph(row.SMILES, row.LogP) for _, row in df_test.iterrows()]

# %% [markdown]
# Choose a model - Here: Graph Isomorphism Network

# %%
class GINModel(torch.nn.Module):
    def __init__(self, dim_h=64):
        super().__init__()

        nn1 = torch.nn.Sequential(
            torch.nn.Linear(5, dim_h),
            torch.nn.ReLU(),
            torch.nn.Linear(dim_h, dim_h)
        )
        nn2 = torch.nn.Sequential(
            torch.nn.Linear(dim_h, dim_h),
            torch.nn.ReLU(),
            torch.nn.Linear(dim_h, dim_h)
        )
        self.conv1 = GINConv(nn1)
        self.conv2 = GINConv(nn2)
        self.lin = torch.nn.Linear(dim_h, 1)

    def forward(self, x, edge_index, batch):
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch)
        return self.lin(x).squeeze(-1)

# %%
def train(model, train_loader, val_loader, epochs=20, lr=0.5e-3):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr) # lr: learning rate
    criterion = torch.nn.MSELoss() # loss function

    for epoch in range(epochs):
        model.train()
        train_losses = []

        for batch in train_loader:
            optimizer.zero_grad() # Reset gradients
            pred = model(batch.x, batch.edge_index, batch.batch) # predict on batch
            loss = criterion(pred, batch.y) # define criterion
            loss.backward() # computes the gradient of the loss
            optimizer.step() # Perform an optimization step
            train_losses.append(loss.item())

        val_loss = evaluate(model, val_loader) # evaluate re-trained model on validation data

        print(f"Epoch {epoch+1:02d} | "
              f"Train Loss = {sum(train_losses)/len(train_losses):.4f} | " # average train loss
              f"Val Loss = {val_loss:.4f}") 


def test(model, test_loader):
    test_loss = evaluate(model, test_loader)
    print(f"\nTest Loss: {test_loss:.4f}")
    
def evaluate(model, loader):
    model.eval()
    criterion = torch.nn.MSELoss()
    losses = []

    with torch.no_grad():
        for batch in loader:
            pred = model(batch.x, batch.edge_index, batch.batch)
            loss = criterion(pred, batch.y)
            losses.append(loss.item())

    return sum(losses) / len(losses)

def create_splits(graphs, train_ratio=0.8, seed=42):
    torch.manual_seed(seed)
    graphs = graphs.copy()
    permutation = torch.randperm(len(graphs))
    graphs = [graphs[i] for i in permutation]

    n = len(graphs)
    n_train = int(n * train_ratio)

    train_graphs = graphs[:n_train]
    val_graphs   = graphs[n_train:]

    return train_graphs, val_graphs

def parity_plot(model, test_loader, title="Parity Plot (Test Set)"):
    model.eval()
    preds = []
    trues = []

    with torch.no_grad():
        for batch in test_loader:
            pred = model(batch.x, batch.edge_index, batch.batch)

            # Ensure correct shapes
            pred = pred.view(-1).cpu()
            y = batch.y.view(-1).cpu()

            preds.append(pred)
            trues.append(y)

    preds = torch.cat(preds).numpy()
    trues = torch.cat(trues).numpy()
    
    print("GNN performance:")
    print('Test R²:', r2_score(trues, preds))
    print('Test RMSE:', root_mean_squared_error(trues, preds))

    # Parity plot
    plt.figure(figsize=(5,5))
    plt.scatter(trues, preds, alpha=0.6)
    plt.plot([trues.min(), trues.max()],
             [trues.min(), trues.max()],
             color='red', linestyle='--', linewidth=2)

    plt.xlabel("True logP")
    plt.ylabel("Predicted logP")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
# load train and validation graphs
graphs_train, graphs_val = create_splits(graphs_training)
train_loader = DataLoader(graphs_train, batch_size=32, shuffle=True)
val_loader   = DataLoader(graphs_val, batch_size=32)

test_loader = DataLoader(graphs_test)

# load model
gin = GINModel()

# Train model
epochs = 500
train(gin, train_loader, val_loader, epochs=epochs)

# Evaluate model
parity_plot(gin, test_loader)
# Out:
# Epoch 01 | Train Loss = 3.5378 | Val Loss = 3.1016
# Epoch 02 | Train Loss = 2.9695 | Val Loss = 2.9756
# Epoch 03 | Train Loss = 3.0059 | Val Loss = 2.9388
# Epoch 04 | Train Loss = 2.9639 | Val Loss = 2.9354
# Epoch 05 | Train Loss = 2.8619 | Val Loss = 3.1763
# Epoch 06 | Train Loss = 2.9283 | Val Loss = 2.9157
# Epoch 07 | Train Loss = 2.7733 | Val Loss = 2.9059
# Epoch 08 | Train Loss = 2.7749 | Val Loss = 2.7407
# Epoch 09 | Train Loss = 2.6599 | Val Loss = 2.9618
# Epoch 10 | Train Loss = 2.6979 | Val Loss = 2.6146
# Epoch 11 | Train Loss = 2.5941 | Val Loss = 2.6250
# Epoch 12 | Train Loss = 2.4902 | Val Loss = 2.4997
# Epoch 13 | Train Loss = 2.5112 | Val Loss = 2.4668
# Epoch 14 | Train Loss = 2.4287 | Val Loss = 2.4703
# Epoch 15 | Train Loss = 2.3470 | Val Loss = 2.3426
# Epoch 16 | Train Loss = 2.3670 | Val Loss = 2.6652
# Epoch 17 | Train Loss = 2.4452 | Val Loss = 2.5353
# Epoch 18 | Train Loss = 2.2951 | Val Loss = 2.4414
# Epoch 19 | Train Loss = 2.2868 | Val Loss = 2.1692
# Epoch 20 | Train Loss = 2.1665 | Val Loss = 2.1471
# Epoch 21 | Train Loss = 2.1209 | Val Loss = 2.2111
# Epoch 22 | Train Loss = 2.0660 | Val Loss = 2.1466
# Epoch 23 | Train Loss = 2.1191 | Val Loss = 2.2105
# Epoch 24 | Train Loss = 2.1002 | Val Loss = 1.9978
# Epoch 25 | Train Loss = 1.9778 | Val Loss = 2.0508
# Epoch 26 | Train Loss = 2.0148 | Val Loss = 1.9353
# Epoch 27 | Train Loss = 1.9273 | Val Loss = 1.8687
# Epoch 28 | Train Loss = 1.8826 | Val Loss = 1.8329
# Epoch 29 | Train Loss = 1.8883 | Val Loss = 1.8854
# Epoch 30 | Train Loss = 1.8145 | Val Loss = 2.4070
# Epoch 31 | Train Loss = 1.8872 | Val Loss = 1.8119
# Epoch 32 | Train Loss = 1.8038 | Val Loss = 2.0378
# Epoch 33 | Train Loss = 1.8534 | Val Loss = 2.1208
# Epoch 34 | Train Loss = 1.8659 | Val Loss = 1.7742
# Epoch 35 | Train Loss = 1.9379 | Val Loss = 1.7221
# Epoch 36 | Train Loss = 1.8749 | Val Loss = 1.8513
# Epoch 37 | Train Loss = 1.8062 | Val Loss = 1.7335
# Epoch 38 | Train Loss = 1.7687 | Val Loss = 2.1229
# Epoch 39 | Train Loss = 1.7459 | Val Loss = 1.7062
# Epoch 40 | Train Loss = 1.9664 | Val Loss = 2.1308
# Epoch 41 | Train Loss = 1.7494 | Val Loss = 1.6631
# Epoch 42 | Train Loss = 1.6270 | Val Loss = 1.6419
# Epoch 43 | Train Loss = 1.6752 | Val Loss = 1.8476
# Epoch 44 | Train Loss = 1.6653 | Val Loss = 1.7521
# Epoch 45 | Train Loss = 1.6386 | Val Loss = 1.6174
# Epoch 46 | Train Loss = 1.6231 | Val Loss = 1.8880
# Epoch 47 | Train Loss = 1.6736 | Val Loss = 1.6549
# Epoch 48 | Train Loss = 1.6601 | Val Loss = 1.5958
# Epoch 49 | Train Loss = 1.5736 | Val Loss = 1.6689
# Epoch 50 | Train Loss = 1.5946 | Val Loss = 1.7012
# Epoch 51 | Train Loss = 1.6663 | Val Loss = 1.9410
# Epoch 52 | Train Loss = 1.7361 | Val Loss = 1.5656
# Epoch 53 | Train Loss = 1.5751 | Val Loss = 1.5986
# Epoch 54 | Train Loss = 1.5265 | Val Loss = 1.5349
# Epoch 55 | Train Loss = 1.5048 | Val Loss = 1.5098
# Epoch 56 | Train Loss = 1.5235 | Val Loss = 1.5453
# Epoch 57 | Train Loss = 1.4697 | Val Loss = 1.4720
# Epoch 58 | Train Loss = 1.4519 | Val Loss = 1.7523
# Epoch 59 | Train Loss = 1.5813 | Val Loss = 1.5726
# Epoch 60 | Train Loss = 1.4333 | Val Loss = 1.6325
# Epoch 61 | Train Loss = 1.4505 | Val Loss = 1.4702
# Epoch 62 | Train Loss = 1.4203 | Val Loss = 1.4522
# Epoch 63 | Train Loss = 1.3978 | Val Loss = 1.4581
# Epoch 64 | Train Loss = 1.3902 | Val Loss = 1.3882
# Epoch 65 | Train Loss = 1.3714 | Val Loss = 1.4345
# Epoch 66 | Train Loss = 1.3689 | Val Loss = 1.4273
# Epoch 67 | Train Loss = 1.3849 | Val Loss = 1.5081
# Epoch 68 | Train Loss = 1.4110 | Val Loss = 1.3535
# Epoch 69 | Train Loss = 1.3786 | Val Loss = 1.3842
# Epoch 70 | Train Loss = 1.4474 | Val Loss = 1.4171
# Epoch 71 | Train Loss = 1.4130 | Val Loss = 2.0202
# Epoch 72 | Train Loss = 1.4567 | Val Loss = 1.4552
# Epoch 73 | Train Loss = 1.6428 | Val Loss = 1.4030
# Epoch 74 | Train Loss = 1.3455 | Val Loss = 1.5693
# Epoch 75 | Train Loss = 1.3433 | Val Loss = 1.5449
# Epoch 76 | Train Loss = 1.4445 | Val Loss = 1.3757
# Epoch 77 | Train Loss = 1.3446 | Val Loss = 1.3936
# Epoch 78 | Train Loss = 1.4197 | Val Loss = 1.5344
# Epoch 79 | Train Loss = 1.3688 | Val Loss = 1.5667
# Epoch 80 | Train Loss = 1.3187 | Val Loss = 1.7173
# Epoch 81 | Train Loss = 1.3379 | Val Loss = 1.7273
# Epoch 82 | Train Loss = 1.5119 | Val Loss = 1.4236
# Epoch 83 | Train Loss = 1.4266 | Val Loss = 1.3306
# Epoch 84 | Train Loss = 1.3281 | Val Loss = 1.3699
# Epoch 85 | Train Loss = 1.3406 | Val Loss = 1.3534
# Epoch 86 | Train Loss = 1.2876 | Val Loss = 1.3126
# Epoch 87 | Train Loss = 1.2655 | Val Loss = 1.2742
# Epoch 88 | Train Loss = 1.2572 | Val Loss = 1.3012
# Epoch 89 | Train Loss = 1.3152 | Val Loss = 1.3503
# Epoch 90 | Train Loss = 1.4247 | Val Loss = 1.5590
# Epoch 91 | Train Loss = 1.3900 | Val Loss = 1.2986
# Epoch 92 | Train Loss = 1.2344 | Val Loss = 1.4476
# Epoch 93 | Train Loss = 1.2799 | Val Loss = 1.5373
# Epoch 94 | Train Loss = 1.2521 | Val Loss = 1.3174
# Epoch 95 | Train Loss = 1.2936 | Val Loss = 1.2952
# Epoch 96 | Train Loss = 1.3345 | Val Loss = 1.3001
# Epoch 97 | Train Loss = 1.3021 | Val Loss = 1.1987
# Epoch 98 | Train Loss = 1.2610 | Val Loss = 1.3262
# Epoch 99 | Train Loss = 1.2620 | Val Loss = 1.2633
# Epoch 100 | Train Loss = 1.3777 | Val Loss = 1.4072
# Epoch 101 | Train Loss = 1.3748 | Val Loss = 1.4826
# Epoch 102 | Train Loss = 1.2483 | Val Loss = 1.3965
# Epoch 103 | Train Loss = 1.2782 | Val Loss = 1.3070
# Epoch 104 | Train Loss = 1.2402 | Val Loss = 1.4286
# Epoch 105 | Train Loss = 1.2304 | Val Loss = 1.2592
# Epoch 106 | Train Loss = 1.1862 | Val Loss = 1.5457
# Epoch 107 | Train Loss = 1.2175 | Val Loss = 1.2205
# Epoch 108 | Train Loss = 1.1887 | Val Loss = 1.4142
# Epoch 109 | Train Loss = 1.1830 | Val Loss = 1.1648
# Epoch 110 | Train Loss = 1.2920 | Val Loss = 1.2709
# Epoch 111 | Train Loss = 1.2478 | Val Loss = 1.3243
# Epoch 112 | Train Loss = 1.1984 | Val Loss = 1.2598
# Epoch 113 | Train Loss = 1.2125 | Val Loss = 1.3014
# Epoch 114 | Train Loss = 1.2257 | Val Loss = 1.2165
# Epoch 115 | Train Loss = 1.1910 | Val Loss = 1.1691
# Epoch 116 | Train Loss = 1.2395 | Val Loss = 1.3863
# Epoch 117 | Train Loss = 1.3108 | Val Loss = 1.3077
# Epoch 118 | Train Loss = 1.2765 | Val Loss = 1.8684
# Epoch 119 | Train Loss = 1.3688 | Val Loss = 1.2701
# Epoch 120 | Train Loss = 1.2452 | Val Loss = 1.1810
# Epoch 121 | Train Loss = 1.1460 | Val Loss = 1.2759
# Epoch 122 | Train Loss = 1.2033 | Val Loss = 1.1747
# Epoch 123 | Train Loss = 1.1758 | Val Loss = 1.3761
# Epoch 124 | Train Loss = 1.2610 | Val Loss = 1.2294
# Epoch 125 | Train Loss = 1.2421 | Val Loss = 1.2290
# Epoch 126 | Train Loss = 1.2813 | Val Loss = 1.2534
# Epoch 127 | Train Loss = 1.1613 | Val Loss = 1.1711
# Epoch 128 | Train Loss = 1.1718 | Val Loss = 1.3264
# Epoch 129 | Train Loss = 1.2712 | Val Loss = 1.1755
# Epoch 130 | Train Loss = 1.1263 | Val Loss = 1.1577
# Epoch 131 | Train Loss = 1.1348 | Val Loss = 1.1946
# Epoch 132 | Train Loss = 1.1924 | Val Loss = 1.3387
# Epoch 133 | Train Loss = 1.1697 | Val Loss = 1.2436
# Epoch 134 | Train Loss = 1.3016 | Val Loss = 1.4027
# Epoch 135 | Train Loss = 1.2542 | Val Loss = 1.1902
# Epoch 136 | Train Loss = 1.2131 | Val Loss = 1.3228
# Epoch 137 | Train Loss = 1.1938 | Val Loss = 1.1958
# Epoch 138 | Train Loss = 1.1706 | Val Loss = 1.1689
# Epoch 139 | Train Loss = 1.1092 | Val Loss = 1.2628
# Epoch 140 | Train Loss = 1.1200 | Val Loss = 1.7225
# Epoch 141 | Train Loss = 1.4102 | Val Loss = 1.2008
# Epoch 142 | Train Loss = 1.1858 | Val Loss = 1.2716
# Epoch 143 | Train Loss = 1.1372 | Val Loss = 1.3594
# Epoch 144 | Train Loss = 1.1813 | Val Loss = 1.3082
# Epoch 145 | Train Loss = 1.1778 | Val Loss = 1.1647
# Epoch 146 | Train Loss = 1.1340 | Val Loss = 1.2189
# Epoch 147 | Train Loss = 1.2223 | Val Loss = 1.2413
# Epoch 148 | Train Loss = 1.2074 | Val Loss = 1.2105
# Epoch 149 | Train Loss = 1.1227 | Val Loss = 1.2571
# Epoch 150 | Train Loss = 1.1194 | Val Loss = 1.1334
# Epoch 151 | Train Loss = 1.1656 | Val Loss = 1.2298
# Epoch 152 | Train Loss = 1.1823 | Val Loss = 1.3617
# Epoch 153 | Train Loss = 1.1347 | Val Loss = 1.2757
# Epoch 154 | Train Loss = 1.1043 | Val Loss = 1.1459
# Epoch 155 | Train Loss = 1.1776 | Val Loss = 1.1981
# Epoch 156 | Train Loss = 1.1547 | Val Loss = 1.2402
# Epoch 157 | Train Loss = 1.1047 | Val Loss = 1.1566
# Epoch 158 | Train Loss = 1.1292 | Val Loss = 1.1923
# Epoch 159 | Train Loss = 1.0803 | Val Loss = 1.3037
# Epoch 160 | Train Loss = 1.1100 | Val Loss = 1.1353
# Epoch 161 | Train Loss = 1.1059 | Val Loss = 1.1497
# Epoch 162 | Train Loss = 1.0806 | Val Loss = 1.1419
# Epoch 163 | Train Loss = 1.2009 | Val Loss = 1.3720
# Epoch 164 | Train Loss = 1.1944 | Val Loss = 1.3488
# Epoch 165 | Train Loss = 1.1934 | Val Loss = 1.1685
# Epoch 166 | Train Loss = 1.0777 | Val Loss = 1.4487
# Epoch 167 | Train Loss = 1.1246 | Val Loss = 1.2719
# Epoch 168 | Train Loss = 1.1477 | Val Loss = 1.1615
# Epoch 169 | Train Loss = 1.0992 | Val Loss = 1.2687
# Epoch 170 | Train Loss = 1.1009 | Val Loss = 1.2201
# Epoch 171 | Train Loss = 1.0996 | Val Loss = 1.2288
# Epoch 172 | Train Loss = 1.2254 | Val Loss = 1.1467
# Epoch 173 | Train Loss = 1.1920 | Val Loss = 1.3070
# Epoch 174 | Train Loss = 1.2790 | Val Loss = 1.3786
# Epoch 175 | Train Loss = 1.1903 | Val Loss = 1.2108
# Epoch 176 | Train Loss = 1.0841 | Val Loss = 1.1554
# Epoch 177 | Train Loss = 1.0830 | Val Loss = 1.6233
# Epoch 178 | Train Loss = 1.1386 | Val Loss = 1.2672
# Epoch 179 | Train Loss = 1.1394 | Val Loss = 1.4176
# Epoch 180 | Train Loss = 1.1306 | Val Loss = 1.1191
# Epoch 181 | Train Loss = 1.0760 | Val Loss = 1.2520
# Epoch 182 | Train Loss = 1.0766 | Val Loss = 1.1438
# Epoch 183 | Train Loss = 1.1204 | Val Loss = 1.2056
# Epoch 184 | Train Loss = 1.0791 | Val Loss = 1.1811
# Epoch 185 | Train Loss = 1.0927 | Val Loss = 1.1661
# Epoch 186 | Train Loss = 1.0718 | Val Loss = 1.2875
# Epoch 187 | Train Loss = 1.1362 | Val Loss = 1.1889
# Epoch 188 | Train Loss = 1.1068 | Val Loss = 1.1745
# Epoch 189 | Train Loss = 1.0990 | Val Loss = 1.1818
# Epoch 190 | Train Loss = 1.0319 | Val Loss = 1.2343
# Epoch 191 | Train Loss = 1.0914 | Val Loss = 1.1438
# Epoch 192 | Train Loss = 1.0364 | Val Loss = 1.2154
# Epoch 193 | Train Loss = 1.1582 | Val Loss = 1.2304
# Epoch 194 | Train Loss = 1.0605 | Val Loss = 1.2662
# Epoch 195 | Train Loss = 1.1015 | Val Loss = 1.1799
# Epoch 196 | Train Loss = 1.0721 | Val Loss = 1.3246
# Epoch 197 | Train Loss = 1.0843 | Val Loss = 1.2292
# Epoch 198 | Train Loss = 1.0734 | Val Loss = 1.1577
# Epoch 199 | Train Loss = 1.0836 | Val Loss = 1.2552
# Epoch 200 | Train Loss = 1.0942 | Val Loss = 1.2476
# Epoch 201 | Train Loss = 1.0634 | Val Loss = 1.2323
# Epoch 202 | Train Loss = 1.0379 | Val Loss = 1.2480
# Epoch 203 | Train Loss = 1.0717 | Val Loss = 1.1642
# Epoch 204 | Train Loss = 1.0510 | Val Loss = 1.2464
# Epoch 205 | Train Loss = 1.0861 | Val Loss = 1.1641
# Epoch 206 | Train Loss = 1.0296 | Val Loss = 1.1361
# Epoch 207 | Train Loss = 1.0152 | Val Loss = 1.1780
# Epoch 208 | Train Loss = 1.0974 | Val Loss = 1.4378
# Epoch 209 | Train Loss = 1.0196 | Val Loss = 1.1991
# Epoch 210 | Train Loss = 1.0265 | Val Loss = 1.1636
# Epoch 211 | Train Loss = 1.0047 | Val Loss = 1.2428
# Epoch 212 | Train Loss = 1.0768 | Val Loss = 1.1180
# Epoch 213 | Train Loss = 1.0693 | Val Loss = 1.3128
# Epoch 214 | Train Loss = 0.9781 | Val Loss = 1.2294
# Epoch 215 | Train Loss = 1.0542 | Val Loss = 1.4785
# Epoch 216 | Train Loss = 1.0486 | Val Loss = 1.2535
# Epoch 217 | Train Loss = 1.0404 | Val Loss = 1.2203
# Epoch 218 | Train Loss = 1.1345 | Val Loss = 1.2787
# Epoch 219 | Train Loss = 1.0769 | Val Loss = 1.1287
# Epoch 220 | Train Loss = 1.0928 | Val Loss = 1.1556
# Epoch 221 | Train Loss = 1.0791 | Val Loss = 1.2166
# Epoch 222 | Train Loss = 1.0375 | Val Loss = 1.1572
# Epoch 223 | Train Loss = 1.0042 | Val Loss = 1.2552
# Epoch 224 | Train Loss = 0.9983 | Val Loss = 1.2572
# Epoch 225 | Train Loss = 1.0571 | Val Loss = 1.2175
# Epoch 226 | Train Loss = 1.0017 | Val Loss = 1.1462
# Epoch 227 | Train Loss = 1.0145 | Val Loss = 1.2312
# Epoch 228 | Train Loss = 1.0141 | Val Loss = 1.2248
# Epoch 229 | Train Loss = 1.0064 | Val Loss = 1.3005
# Epoch 230 | Train Loss = 1.0193 | Val Loss = 1.2353
# Epoch 231 | Train Loss = 0.9865 | Val Loss = 1.1616
# Epoch 232 | Train Loss = 1.0318 | Val Loss = 1.2799
# Epoch 233 | Train Loss = 0.9889 | Val Loss = 1.2078
# Epoch 234 | Train Loss = 0.9908 | Val Loss = 1.1597
# Epoch 235 | Train Loss = 0.9763 | Val Loss = 1.1502
# Epoch 236 | Train Loss = 1.0556 | Val Loss = 1.2195
# Epoch 237 | Train Loss = 1.1046 | Val Loss = 1.4045
# Epoch 238 | Train Loss = 1.0443 | Val Loss = 1.1194
# Epoch 239 | Train Loss = 1.0223 | Val Loss = 1.1959
# Epoch 240 | Train Loss = 0.9674 | Val Loss = 1.2752
# Epoch 241 | Train Loss = 0.9864 | Val Loss = 1.2273
# Epoch 242 | Train Loss = 1.0439 | Val Loss = 1.2322
# Epoch 243 | Train Loss = 1.0153 | Val Loss = 1.1673
# Epoch 244 | Train Loss = 0.9401 | Val Loss = 1.1661
# Epoch 245 | Train Loss = 0.9874 | Val Loss = 1.1487
# Epoch 246 | Train Loss = 0.9966 | Val Loss = 1.2486
# Epoch 247 | Train Loss = 1.0221 | Val Loss = 1.1745
# Epoch 248 | Train Loss = 1.0219 | Val Loss = 1.2309
# Epoch 249 | Train Loss = 0.9744 | Val Loss = 1.2294
# Epoch 250 | Train Loss = 0.9452 | Val Loss = 1.1905
# Epoch 251 | Train Loss = 0.9648 | Val Loss = 1.1578
# Epoch 252 | Train Loss = 0.9225 | Val Loss = 1.1314
# Epoch 253 | Train Loss = 0.9619 | Val Loss = 1.1966
# Epoch 254 | Train Loss = 0.9746 | Val Loss = 1.1966
# Epoch 255 | Train Loss = 0.9884 | Val Loss = 1.1878
# Epoch 256 | Train Loss = 1.0933 | Val Loss = 1.3868
# Epoch 257 | Train Loss = 0.9859 | Val Loss = 1.2355
# Epoch 258 | Train Loss = 1.0175 | Val Loss = 1.2849
# Epoch 259 | Train Loss = 0.9509 | Val Loss = 1.2866
# Epoch 260 | Train Loss = 0.9735 | Val Loss = 1.1346
# Epoch 261 | Train Loss = 0.9195 | Val Loss = 1.3142
# Epoch 262 | Train Loss = 0.9727 | Val Loss = 1.1709
# Epoch 263 | Train Loss = 0.9887 | Val Loss = 1.3340
# Epoch 264 | Train Loss = 0.9734 | Val Loss = 1.1879
# Epoch 265 | Train Loss = 0.9744 | Val Loss = 1.1597
# Epoch 266 | Train Loss = 1.0101 | Val Loss = 1.2583
# Epoch 267 | Train Loss = 0.9553 | Val Loss = 1.1654
# Epoch 268 | Train Loss = 0.9162 | Val Loss = 1.2191
# Epoch 269 | Train Loss = 0.9069 | Val Loss = 1.2583
# Epoch 270 | Train Loss = 0.9575 | Val Loss = 1.1435
# Epoch 271 | Train Loss = 0.9510 | Val Loss = 1.1550
# Epoch 272 | Train Loss = 0.9623 | Val Loss = 1.1225
# Epoch 273 | Train Loss = 0.9773 | Val Loss = 1.1503
# Epoch 274 | Train Loss = 0.9296 | Val Loss = 1.2593
# Epoch 275 | Train Loss = 1.0054 | Val Loss = 1.0511
# Epoch 276 | Train Loss = 0.9899 | Val Loss = 1.5976
# Epoch 277 | Train Loss = 0.9016 | Val Loss = 1.1624
# Epoch 278 | Train Loss = 0.9550 | Val Loss = 1.2821
# Epoch 279 | Train Loss = 0.9312 | Val Loss = 1.2745
# Epoch 280 | Train Loss = 0.9047 | Val Loss = 1.1490
# Epoch 281 | Train Loss = 0.9479 | Val Loss = 1.2959
# Epoch 282 | Train Loss = 0.9211 | Val Loss = 1.2074
# Epoch 283 | Train Loss = 0.8764 | Val Loss = 1.2304
# Epoch 284 | Train Loss = 1.0017 | Val Loss = 1.2146
# Epoch 285 | Train Loss = 0.9099 | Val Loss = 1.2092
# Epoch 286 | Train Loss = 0.9258 | Val Loss = 1.2375
# Epoch 287 | Train Loss = 0.9333 | Val Loss = 1.0967
# Epoch 288 | Train Loss = 0.8911 | Val Loss = 1.1422
# Epoch 289 | Train Loss = 0.9270 | Val Loss = 1.2399
# Epoch 290 | Train Loss = 0.9307 | Val Loss = 1.1637
# Epoch 291 | Train Loss = 0.8694 | Val Loss = 1.1854
# Epoch 292 | Train Loss = 0.9226 | Val Loss = 1.1972
# Epoch 293 | Train Loss = 0.9511 | Val Loss = 1.1018
# Epoch 294 | Train Loss = 0.9024 | Val Loss = 1.1497
# Epoch 295 | Train Loss = 0.9109 | Val Loss = 1.1639
# Epoch 296 | Train Loss = 0.9137 | Val Loss = 1.1226
# Epoch 297 | Train Loss = 0.9356 | Val Loss = 1.3603
# Epoch 298 | Train Loss = 0.9519 | Val Loss = 1.3549
# Epoch 299 | Train Loss = 0.8824 | Val Loss = 1.1232
# Epoch 300 | Train Loss = 0.8725 | Val Loss = 1.1615
# Epoch 301 | Train Loss = 0.8652 | Val Loss = 1.1973
# Epoch 302 | Train Loss = 0.9341 | Val Loss = 1.2184
# Epoch 303 | Train Loss = 0.8673 | Val Loss = 1.1957
# Epoch 304 | Train Loss = 0.8774 | Val Loss = 1.0891
# Epoch 305 | Train Loss = 0.8504 | Val Loss = 1.1648
# Epoch 306 | Train Loss = 0.8987 | Val Loss = 1.1902
# Epoch 307 | Train Loss = 0.8947 | Val Loss = 1.2859
# Epoch 308 | Train Loss = 0.9355 | Val Loss = 1.1294
# Epoch 309 | Train Loss = 0.8571 | Val Loss = 1.1937
# Epoch 310 | Train Loss = 0.8913 | Val Loss = 1.0723
# Epoch 311 | Train Loss = 0.8917 | Val Loss = 1.2687
# Epoch 312 | Train Loss = 0.8546 | Val Loss = 1.1328
# Epoch 313 | Train Loss = 0.8392 | Val Loss = 1.3276
# Epoch 314 | Train Loss = 0.8759 | Val Loss = 1.2996
# Epoch 315 | Train Loss = 0.9527 | Val Loss = 1.4171
# Epoch 316 | Train Loss = 0.8903 | Val Loss = 1.0842
# Epoch 317 | Train Loss = 0.8764 | Val Loss = 1.1734
# Epoch 318 | Train Loss = 0.8514 | Val Loss = 1.1549
# Epoch 319 | Train Loss = 0.8699 | Val Loss = 1.1741
# Epoch 320 | Train Loss = 0.8542 | Val Loss = 1.1280
# Epoch 321 | Train Loss = 0.8522 | Val Loss = 1.1446
# Epoch 322 | Train Loss = 0.8630 | Val Loss = 1.2053
# Epoch 323 | Train Loss = 0.9306 | Val Loss = 1.2196
# Epoch 324 | Train Loss = 0.9114 | Val Loss = 1.2251
# Epoch 325 | Train Loss = 0.9259 | Val Loss = 1.1134
# Epoch 326 | Train Loss = 0.8641 | Val Loss = 1.1365
# Epoch 327 | Train Loss = 0.9312 | Val Loss = 1.1363
# Epoch 328 | Train Loss = 0.9042 | Val Loss = 1.1510
# Epoch 329 | Train Loss = 0.8706 | Val Loss = 1.1676
# Epoch 330 | Train Loss = 0.8945 | Val Loss = 1.0763
# Epoch 331 | Train Loss = 0.8682 | Val Loss = 1.1148
# Epoch 332 | Train Loss = 0.8405 | Val Loss = 1.2357
# Epoch 333 | Train Loss = 0.8842 | Val Loss = 1.1580
# Epoch 334 | Train Loss = 0.8634 | Val Loss = 1.2247
# Epoch 335 | Train Loss = 0.8917 | Val Loss = 1.2260
# Epoch 336 | Train Loss = 0.8644 | Val Loss = 1.2720
# Epoch 337 | Train Loss = 0.9277 | Val Loss = 1.5617
# Epoch 338 | Train Loss = 0.9709 | Val Loss = 1.2535
# Epoch 339 | Train Loss = 0.8695 | Val Loss = 1.1459
# Epoch 340 | Train Loss = 0.8379 | Val Loss = 1.1424
# Epoch 341 | Train Loss = 0.8228 | Val Loss = 1.1639
# Epoch 342 | Train Loss = 0.8548 | Val Loss = 1.2572
# Epoch 343 | Train Loss = 0.8347 | Val Loss = 1.2154
# Epoch 344 | Train Loss = 0.8417 | Val Loss = 1.1779
# Epoch 345 | Train Loss = 0.8327 | Val Loss = 1.1150
# Epoch 346 | Train Loss = 0.8594 | Val Loss = 1.1211
# Epoch 347 | Train Loss = 0.8666 | Val Loss = 1.1349
# Epoch 348 | Train Loss = 0.8574 | Val Loss = 1.2878
# Epoch 349 | Train Loss = 0.8916 | Val Loss = 1.3995
# Epoch 350 | Train Loss = 0.8714 | Val Loss = 1.1176
# Epoch 351 | Train Loss = 0.8962 | Val Loss = 1.0796
# Epoch 352 | Train Loss = 0.8810 | Val Loss = 1.1505
# Epoch 353 | Train Loss = 0.9016 | Val Loss = 1.1396
# Epoch 354 | Train Loss = 0.8166 | Val Loss = 1.0965
# Epoch 355 | Train Loss = 0.8359 | Val Loss = 1.1263
# Epoch 356 | Train Loss = 0.8760 | Val Loss = 1.1422
# Epoch 357 | Train Loss = 0.8517 | Val Loss = 1.1081
# Epoch 358 | Train Loss = 0.9114 | Val Loss = 1.0992
# Epoch 359 | Train Loss = 0.9586 | Val Loss = 1.4014
# Epoch 360 | Train Loss = 0.8853 | Val Loss = 1.4635
# Epoch 361 | Train Loss = 0.8831 | Val Loss = 1.0939
# Epoch 362 | Train Loss = 0.8485 | Val Loss = 1.2804
# Epoch 363 | Train Loss = 0.8135 | Val Loss = 1.1776
# Epoch 364 | Train Loss = 0.8339 | Val Loss = 1.1228
# Epoch 365 | Train Loss = 0.7828 | Val Loss = 1.1733
# Epoch 366 | Train Loss = 0.9119 | Val Loss = 1.1287
# Epoch 367 | Train Loss = 0.8277 | Val Loss = 1.1527
# Epoch 368 | Train Loss = 0.9241 | Val Loss = 1.3019
# Epoch 369 | Train Loss = 0.8512 | Val Loss = 1.3077
# Epoch 370 | Train Loss = 0.8861 | Val Loss = 1.2794
# Epoch 371 | Train Loss = 0.8332 | Val Loss = 1.2120
# Epoch 372 | Train Loss = 0.8256 | Val Loss = 1.1714
# Epoch 373 | Train Loss = 0.8490 | Val Loss = 1.0478
# Epoch 374 | Train Loss = 0.8243 | Val Loss = 1.1937
# Epoch 375 | Train Loss = 0.8361 | Val Loss = 1.1781
# Epoch 376 | Train Loss = 0.8141 | Val Loss = 1.2439
# Epoch 377 | Train Loss = 0.8415 | Val Loss = 1.1635
# Epoch 378 | Train Loss = 0.7821 | Val Loss = 1.1414
# Epoch 379 | Train Loss = 0.7853 | Val Loss = 1.1213
# Epoch 380 | Train Loss = 0.7876 | Val Loss = 1.3005
# Epoch 381 | Train Loss = 0.8361 | Val Loss = 1.1933
# Epoch 382 | Train Loss = 0.8104 | Val Loss = 1.3406
# Epoch 383 | Train Loss = 0.8406 | Val Loss = 1.2265
# Epoch 384 | Train Loss = 0.8614 | Val Loss = 1.1684
# Epoch 385 | Train Loss = 0.8986 | Val Loss = 1.0978
# Epoch 386 | Train Loss = 0.8479 | Val Loss = 1.1127
# Epoch 387 | Train Loss = 0.7948 | Val Loss = 1.0927
# Epoch 388 | Train Loss = 0.7742 | Val Loss = 1.1971
# Epoch 389 | Train Loss = 0.8106 | Val Loss = 1.1265
# Epoch 390 | Train Loss = 0.8010 | Val Loss = 1.1219
# Epoch 391 | Train Loss = 0.7895 | Val Loss = 1.2382
# Epoch 392 | Train Loss = 0.8132 | Val Loss = 1.1385
# Epoch 393 | Train Loss = 0.8862 | Val Loss = 1.1578
# Epoch 394 | Train Loss = 0.8316 | Val Loss = 1.1423
# Epoch 395 | Train Loss = 0.7966 | Val Loss = 1.1635
# Epoch 396 | Train Loss = 0.7750 | Val Loss = 1.1937
# Epoch 397 | Train Loss = 0.8366 | Val Loss = 1.1933
# Epoch 398 | Train Loss = 0.7934 | Val Loss = 1.2326
# Epoch 399 | Train Loss = 0.7875 | Val Loss = 1.2711
# Epoch 400 | Train Loss = 0.7619 | Val Loss = 1.1323
# Epoch 401 | Train Loss = 0.8594 | Val Loss = 1.0935
# Epoch 402 | Train Loss = 0.7867 | Val Loss = 1.1408
# Epoch 403 | Train Loss = 0.7976 | Val Loss = 1.3314
# Epoch 404 | Train Loss = 0.7734 | Val Loss = 1.1533
# Epoch 405 | Train Loss = 0.7789 | Val Loss = 1.2192
# Epoch 406 | Train Loss = 0.7883 | Val Loss = 1.2151
# Epoch 407 | Train Loss = 0.8299 | Val Loss = 1.1690
# Epoch 408 | Train Loss = 0.8115 | Val Loss = 1.2676
# Epoch 409 | Train Loss = 0.7821 | Val Loss = 1.1076
# Epoch 410 | Train Loss = 0.7617 | Val Loss = 1.2227
# Epoch 411 | Train Loss = 0.7672 | Val Loss = 1.2046
# Epoch 412 | Train Loss = 0.7682 | Val Loss = 1.1217
# Epoch 413 | Train Loss = 0.7624 | Val Loss = 1.2162
# Epoch 414 | Train Loss = 0.7720 | Val Loss = 1.2237
# Epoch 415 | Train Loss = 0.8289 | Val Loss = 1.1306
# Epoch 416 | Train Loss = 0.8100 | Val Loss = 1.1241
# Epoch 417 | Train Loss = 0.8053 | Val Loss = 1.1297
# Epoch 418 | Train Loss = 0.8031 | Val Loss = 1.1562
# Epoch 419 | Train Loss = 0.8379 | Val Loss = 1.1757
# Epoch 420 | Train Loss = 0.8369 | Val Loss = 1.2040
# Epoch 421 | Train Loss = 0.7687 | Val Loss = 1.1929
# Epoch 422 | Train Loss = 0.7495 | Val Loss = 1.2131
# Epoch 423 | Train Loss = 0.7790 | Val Loss = 1.3667
# Epoch 424 | Train Loss = 0.7805 | Val Loss = 1.2332
# Epoch 425 | Train Loss = 0.7822 | Val Loss = 1.1274
# Epoch 426 | Train Loss = 0.7384 | Val Loss = 1.2635
# Epoch 427 | Train Loss = 0.7380 | Val Loss = 1.1963
# Epoch 428 | Train Loss = 0.7770 | Val Loss = 1.1482
# Epoch 429 | Train Loss = 0.7782 | Val Loss = 1.1350
# Epoch 430 | Train Loss = 0.7823 | Val Loss = 1.1558
# Epoch 431 | Train Loss = 0.7747 | Val Loss = 1.0922
# Epoch 432 | Train Loss = 0.7402 | Val Loss = 1.1311
# Epoch 433 | Train Loss = 0.7441 | Val Loss = 1.1669
# Epoch 434 | Train Loss = 0.8022 | Val Loss = 1.0802
# Epoch 435 | Train Loss = 0.7602 | Val Loss = 1.2002
# Epoch 436 | Train Loss = 0.7967 | Val Loss = 1.1055
# Epoch 437 | Train Loss = 0.7728 | Val Loss = 1.1726
# Epoch 438 | Train Loss = 0.7222 | Val Loss = 1.1272
# Epoch 439 | Train Loss = 0.7263 | Val Loss = 1.1256
# Epoch 440 | Train Loss = 0.7658 | Val Loss = 1.2706
# Epoch 441 | Train Loss = 0.7324 | Val Loss = 1.1353
# Epoch 442 | Train Loss = 0.8210 | Val Loss = 1.4730
# Epoch 443 | Train Loss = 0.9337 | Val Loss = 1.1952
# Epoch 444 | Train Loss = 0.7539 | Val Loss = 1.1193
# Epoch 445 | Train Loss = 0.7364 | Val Loss = 1.3663
# Epoch 446 | Train Loss = 0.7498 | Val Loss = 1.1885
# Epoch 447 | Train Loss = 0.7229 | Val Loss = 1.2014
# Epoch 448 | Train Loss = 0.7511 | Val Loss = 1.0923
# Epoch 449 | Train Loss = 0.7252 | Val Loss = 1.1653
# Epoch 450 | Train Loss = 0.8185 | Val Loss = 1.2331
# Epoch 451 | Train Loss = 0.7983 | Val Loss = 1.1336
# Epoch 452 | Train Loss = 0.7889 | Val Loss = 1.1745
# Epoch 453 | Train Loss = 0.7499 | Val Loss = 1.0945
# Epoch 454 | Train Loss = 0.7207 | Val Loss = 1.4789
# Epoch 455 | Train Loss = 0.7240 | Val Loss = 1.0935
# Epoch 456 | Train Loss = 0.7211 | Val Loss = 1.1147
# Epoch 457 | Train Loss = 0.7184 | Val Loss = 1.0932
# Epoch 458 | Train Loss = 0.7945 | Val Loss = 1.1889
# Epoch 459 | Train Loss = 0.8165 | Val Loss = 1.1412
# Epoch 460 | Train Loss = 0.7466 | Val Loss = 1.2055
# Epoch 461 | Train Loss = 0.7907 | Val Loss = 1.1240
# Epoch 462 | Train Loss = 0.7290 | Val Loss = 1.1471
# Epoch 463 | Train Loss = 0.6953 | Val Loss = 1.2159
# Epoch 464 | Train Loss = 0.6985 | Val Loss = 1.1096
# Epoch 465 | Train Loss = 0.7186 | Val Loss = 1.1613
# Epoch 466 | Train Loss = 0.7115 | Val Loss = 1.1298
# Epoch 467 | Train Loss = 0.7485 | Val Loss = 1.1068
# Epoch 468 | Train Loss = 0.7592 | Val Loss = 1.1744
# Epoch 469 | Train Loss = 0.7303 | Val Loss = 1.0379
# Epoch 470 | Train Loss = 0.7731 | Val Loss = 1.0815
# Epoch 471 | Train Loss = 0.7489 | Val Loss = 1.0835
# Epoch 472 | Train Loss = 0.7566 | Val Loss = 1.1810
# Epoch 473 | Train Loss = 0.6799 | Val Loss = 1.1744
# Epoch 474 | Train Loss = 0.7179 | Val Loss = 1.1792
# Epoch 475 | Train Loss = 0.7100 | Val Loss = 1.0894
# Epoch 476 | Train Loss = 0.7212 | Val Loss = 1.1350
# Epoch 477 | Train Loss = 0.7663 | Val Loss = 1.0673
# Epoch 478 | Train Loss = 0.7447 | Val Loss = 1.1411
# Epoch 479 | Train Loss = 0.7237 | Val Loss = 1.1592
# Epoch 480 | Train Loss = 0.7248 | Val Loss = 1.2226
# Epoch 481 | Train Loss = 0.7035 | Val Loss = 1.1650
# Epoch 482 | Train Loss = 0.6857 | Val Loss = 1.1215
# Epoch 483 | Train Loss = 0.7504 | Val Loss = 1.2172
# Epoch 484 | Train Loss = 0.7514 | Val Loss = 1.1812
# Epoch 485 | Train Loss = 0.7731 | Val Loss = 1.1314
# Epoch 486 | Train Loss = 0.7553 | Val Loss = 1.1763
# Epoch 487 | Train Loss = 0.7239 | Val Loss = 1.4420
# Epoch 488 | Train Loss = 0.7285 | Val Loss = 1.0930
# Epoch 489 | Train Loss = 0.6813 | Val Loss = 1.1308
# Epoch 490 | Train Loss = 0.6965 | Val Loss = 1.2169
# Epoch 491 | Train Loss = 0.7171 | Val Loss = 1.2152
# Epoch 492 | Train Loss = 0.7972 | Val Loss = 1.2481
# Epoch 493 | Train Loss = 0.7492 | Val Loss = 1.1638
# Epoch 494 | Train Loss = 0.7012 | Val Loss = 1.1036
# Epoch 495 | Train Loss = 0.6885 | Val Loss = 1.0655
# Epoch 496 | Train Loss = 0.6625 | Val Loss = 1.1455
# Epoch 497 | Train Loss = 0.7187 | Val Loss = 1.1254
# Epoch 498 | Train Loss = 0.6947 | Val Loss = 1.2041
# Epoch 499 | Train Loss = 0.7632 | Val Loss = 1.1178
# Epoch 500 | Train Loss = 0.7220 | Val Loss = 1.1874
# GNN performance:
# Test R²: 0.7004079818725586
# Test RMSE: 1.0409601926803589

# %% [markdown]
# ### Discussion points
# 1) Which model (supervised or unsupervised) performed better on the test set, and why?
# 2) What did you try to improve model performance of your GNN? What did work, what did not work?
# 3) Which challenges did you face in the process of building the models?
# 4) Which of your two models would you recommend to a chemist for predicting logP, and why?
