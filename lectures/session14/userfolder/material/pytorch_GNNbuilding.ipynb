# %% [markdown]
# # Build GNNs with Pytorch
# Using the esol_modified.csv data set to predict logP from structure

# %%
import math
import numpy
import pandas as pd
from pathlib import Path
import os
from rdkit import Chem

import torch
import torch.nn.functional as Fun
from torch.nn import Linear, Sequential, BatchNorm1d, ReLU
from torch_geometric.nn import GCNConv, GINConv, GATConv
from torch_geometric.loader import DataLoader
from torch_geometric.nn import global_mean_pool, global_add_pool
from torch_geometric.data import Data

# %% [markdown]
# First, load the esol data set from session11

# %%
df = pd.read_csv(os.path.join("/Users/raphaeland./Documents/Uni/Master/Modules/DSA104/lectures/session11/material/esol_modified.csv")).dropna(subset=["SMILES"])
# we will have trouble if the SMILES contains only a single atom (no graph can be constructed)
df = df.loc[df.SMILES != 'C']

# %% [markdown]
# Next, we encode the SMILES in the dataset into graph objects using RDKit

# %%
def atom_features(atom): # Create a tensor for atom features, length = 5
    return torch.tensor([
        atom.GetAtomicNum(),
        atom.GetTotalDegree(),
        atom.GetFormalCharge(),
        int(atom.GetIsAromatic()),
        atom.GetTotalNumHs(),
    ], dtype=torch.float)

def bond_features(bond): # Create a tensor for bond features, length = 6
    bt = bond.GetBondType()
    return torch.tensor([
        bt == Chem.rdchem.BondType.SINGLE,
        bt == Chem.rdchem.BondType.DOUBLE,
        bt == Chem.rdchem.BondType.TRIPLE,
        bt == Chem.rdchem.BondType.AROMATIC,
        bond.GetIsConjugated(),
        bond.IsInRing(),
    ], dtype=torch.float)

# %%
def smiles_to_graph(smiles, y):
    mol = Chem.MolFromSmiles(smiles) # Create a RDKit mol object from the smiles

    # Calculate atom features for all atoms in the molecule
    x = torch.stack([atom_features(atom) for atom in mol.GetAtoms()], dim=0)

    # Edges
    edge_index = []
    edge_attr = []
    
    # Iterate through all bonds in the molecule
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()

        # Represent molecule as an undirected graph --> add both directions
        edge_index.append([i, j]) # left to right
        edge_index.append([j, i]) # right to left

        bf = bond_features(bond) # calculate bond features 
        edge_attr.append(bf)
        edge_attr.append(bf) # add two times, once for forward and once for backwards edge

    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous() 
    edge_attr  = torch.stack(edge_attr, dim=0)

    # Target property: logP
    y = torch.tensor([y], dtype=torch.float)
    
    # x: atom stack, y: logP
    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)

# %% [markdown]
# Obtain Graph representation of the data

# %%
graphs = [smiles_to_graph(row.SMILES, row.LogP) for _, row in df.iterrows()]

# %%
class GCNModel(torch.nn.Module):
    def __init__(self, dim_h=64): # dim_h: Size of hidden layer
        super().__init__()
        self.conv1 = GCNConv(5, dim_h) # first convolution layer: in_channels: 5, number of atom features
        self.conv2 = GCNConv(dim_h, dim_h) # second convolution layer
        self.lin = torch.nn.Linear(dim_h, 1) # output layer
        
    # Define how the data flows through the layers
    def forward(self, x, edge_index, batch):
        x = torch.relu(self.conv1(x, edge_index))  # input layer: convolution + activation function (ReLu)
        x = torch.relu(self.conv2(x, edge_index))  # hidden layer: convolution + activation function (ReLu)
        x = global_mean_pool(x, batch)             # pooling function
        return self.lin(x).squeeze(-1)

# %%
class GINModel(torch.nn.Module):
    def __init__(self, dim_h=64):
        super().__init__()

        nn1 = torch.nn.Sequential(
            torch.nn.Linear(5, dim_h),
            torch.nn.ReLU(),
            torch.nn.Linear(dim_h, dim_h)
        )
        nn2 = torch.nn.Sequential(
            torch.nn.Linear(dim_h, dim_h),
            torch.nn.ReLU(),
            torch.nn.Linear(dim_h, dim_h)
        )

        self.conv1 = GINConv(nn1)
        self.conv2 = GINConv(nn2)

        self.lin = torch.nn.Linear(dim_h, 1)

    def forward(self, x, edge_index, batch):
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch) # try: global_add_pool(x, batch)
        return self.lin(x).squeeze(-1)

# %%
class GATModel(torch.nn.Module):
    def __init__(self, dim_h=64, heads=4):
        super().__init__()

        # Input layer
        self.conv1 = GATConv(
            in_channels=5,        # your atom feature size
            out_channels=dim_h,  # hidden dimension per head
            heads=heads,
            dropout=0.1,
            concat=True           # concatenates heads --> output = hidden * heads
        )

        # Second layer
        self.conv2 = GATConv(
            in_channels=dim_h * heads,
            out_channels=dim_h,
            heads=1,
            dropout=0.1,
            concat=False          # final output shape = (hidden,)
        )

        self.lin = torch.nn.Linear(dim_h, 1)

    def forward(self, x, edge_index, batch):
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch)
        return self.lin(x).squeeze(-1)

# %%
def train(model, train_loader, val_loader, epochs=20, lr=1e-3):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr) # lr: learning rate
    criterion = torch.nn.MSELoss() # loss function

    for epoch in range(epochs):
        model.train()
        train_losses = []

        for batch in train_loader:
            optimizer.zero_grad() # Reset gradients
            pred = model(batch.x, batch.edge_index, batch.batch) # predict on batch
            loss = criterion(pred, batch.y) # define criterion
            loss.backward() # computes the gradient of the loss
            optimizer.step() # Perform an optimization step
            train_losses.append(loss.item())

        val_loss = evaluate(model, val_loader) # evaluate re-trained model on validation data

        print(f"Epoch {epoch+1:02d} | "
              f"Train Loss = {sum(train_losses)/len(train_losses):.4f} | " # average train loss
              f"Val Loss = {val_loss:.4f}") 


def test(model, test_loader):
    test_loss = evaluate(model, test_loader)
    print(f"\nTest Loss: {test_loss:.4f}")

# %%
def create_splits(graphs, train_ratio=0.8, val_ratio=0.1, seed=42):
    torch.manual_seed(seed)
    graphs = graphs.copy()
    permutation = torch.randperm(len(graphs))
    graphs = [graphs[i] for i in permutation]

    n = len(graphs)
    n_train = int(n * train_ratio)
    n_val = int(n * val_ratio)

    train_graphs = graphs[:n_train]
    val_graphs   = graphs[n_train:n_train + n_val]
    test_graphs  = graphs[n_train + n_val:]

    return train_graphs, val_graphs, test_graphs

train_graphs, val_graphs, test_graphs = create_splits(graphs)

train_loader = DataLoader(train_graphs, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_graphs, batch_size=32)
test_loader  = DataLoader(test_graphs, batch_size=32)

# %%
def evaluate(model, loader):
    model.eval()
    criterion = torch.nn.MSELoss()
    losses = []

    with torch.no_grad():
        for batch in loader:
            pred = model(batch.x, batch.edge_index, batch.batch)
            loss = criterion(pred, batch.y)
            losses.append(loss.item())

    return sum(losses) / len(losses)

# %% [markdown]
# Now, we load the data and train the GNNs

# %%
loader = DataLoader(graphs, batch_size=100, shuffle=True)

# %%
# training GCN for 10 epochs
gcn = GCNModel()
gin = GINModel()
gat = GATModel()

epochs = 100

print("\n=== Training GCN ===")
train(gcn, train_loader, val_loader, epochs=epochs)
test(gcn, test_loader)

print("\n=== Training GIN ===")
train(gin, train_loader, val_loader, epochs=epochs)
test(gin, test_loader)

print("\n=== Training GAT ===")
train(gat, train_loader, val_loader, epochs=epochs)
test(gat, test_loader)
# Out:
# === Training GCN ===
# Epoch 01 | Train Loss = 4.6427 | Val Loss = 5.0199
# Epoch 02 | Train Loss = 3.3968 | Val Loss = 5.2731
# Epoch 03 | Train Loss = 3.3226 | Val Loss = 5.0158
# Epoch 04 | Train Loss = 3.3927 | Val Loss = 5.0429
# Epoch 05 | Train Loss = 3.2127 | Val Loss = 5.0100
# Epoch 06 | Train Loss = 3.2344 | Val Loss = 4.9595
# Epoch 07 | Train Loss = 3.1663 | Val Loss = 4.7850
# Epoch 08 | Train Loss = 3.2009 | Val Loss = 4.7261
# Epoch 09 | Train Loss = 3.1525 | Val Loss = 4.7696
# Epoch 10 | Train Loss = 3.0075 | Val Loss = 4.6330
# Epoch 11 | Train Loss = 2.9720 | Val Loss = 4.5526
# Epoch 12 | Train Loss = 3.0014 | Val Loss = 4.5447
# Epoch 13 | Train Loss = 3.0081 | Val Loss = 4.5548
# Epoch 14 | Train Loss = 2.9789 | Val Loss = 4.4482
# Epoch 15 | Train Loss = 2.9880 | Val Loss = 4.3783
# Epoch 16 | Train Loss = 2.8850 | Val Loss = 4.5379
# Epoch 17 | Train Loss = 2.9229 | Val Loss = 4.4573
# Epoch 18 | Train Loss = 2.8859 | Val Loss = 4.3085
# Epoch 19 | Train Loss = 3.1028 | Val Loss = 4.2675
# Epoch 20 | Train Loss = 2.8059 | Val Loss = 4.2310
# Epoch 21 | Train Loss = 2.8069 | Val Loss = 4.1509
# Epoch 22 | Train Loss = 2.9607 | Val Loss = 4.0941
# Epoch 23 | Train Loss = 2.7772 | Val Loss = 4.0519
# Epoch 24 | Train Loss = 2.7560 | Val Loss = 4.2070
# Epoch 25 | Train Loss = 2.7427 | Val Loss = 3.9844
# Epoch 26 | Train Loss = 2.6751 | Val Loss = 4.2011
# Epoch 27 | Train Loss = 2.6387 | Val Loss = 4.0916
# Epoch 28 | Train Loss = 2.6529 | Val Loss = 3.7804
# Epoch 29 | Train Loss = 2.6056 | Val Loss = 3.7375
# Epoch 30 | Train Loss = 2.6273 | Val Loss = 3.6753
# Epoch 31 | Train Loss = 2.7160 | Val Loss = 3.5943
# Epoch 32 | Train Loss = 2.6272 | Val Loss = 3.5820
# Epoch 33 | Train Loss = 2.5043 | Val Loss = 3.5120
# Epoch 34 | Train Loss = 2.5039 | Val Loss = 3.6628
# Epoch 35 | Train Loss = 2.4413 | Val Loss = 3.3986
# Epoch 36 | Train Loss = 2.4334 | Val Loss = 3.3570
# Epoch 37 | Train Loss = 2.4069 | Val Loss = 3.3251
# Epoch 38 | Train Loss = 2.7390 | Val Loss = 3.3324
# Epoch 39 | Train Loss = 2.4721 | Val Loss = 3.2358
# Epoch 40 | Train Loss = 2.4418 | Val Loss = 3.2538
# Epoch 41 | Train Loss = 2.3491 | Val Loss = 3.1611
# Epoch 42 | Train Loss = 2.3346 | Val Loss = 3.1774
# Epoch 43 | Train Loss = 2.3708 | Val Loss = 3.2387
# Epoch 44 | Train Loss = 2.6324 | Val Loss = 3.0387
# Epoch 45 | Train Loss = 2.3687 | Val Loss = 3.2224
# Epoch 46 | Train Loss = 2.2736 | Val Loss = 3.0043
# Epoch 47 | Train Loss = 2.3286 | Val Loss = 2.9950
# Epoch 48 | Train Loss = 2.2771 | Val Loss = 3.0370
# Epoch 49 | Train Loss = 2.2405 | Val Loss = 2.9837
# Epoch 50 | Train Loss = 2.2475 | Val Loss = 2.8694
# Epoch 51 | Train Loss = 2.2699 | Val Loss = 3.1898
# Epoch 52 | Train Loss = 2.3026 | Val Loss = 2.9966
# Epoch 53 | Train Loss = 2.2746 | Val Loss = 2.9184
# Epoch 54 | Train Loss = 2.2087 | Val Loss = 2.8304
# Epoch 55 | Train Loss = 2.2428 | Val Loss = 2.8100
# Epoch 56 | Train Loss = 2.2327 | Val Loss = 3.0663
# Epoch 57 | Train Loss = 2.2112 | Val Loss = 2.7707
# Epoch 58 | Train Loss = 2.3222 | Val Loss = 2.9315
# Epoch 59 | Train Loss = 2.2037 | Val Loss = 2.7388
# Epoch 60 | Train Loss = 2.1706 | Val Loss = 2.7484
# Epoch 61 | Train Loss = 2.1723 | Val Loss = 2.8628
# Epoch 62 | Train Loss = 2.1781 | Val Loss = 2.6842
# Epoch 63 | Train Loss = 2.3393 | Val Loss = 2.7802
# Epoch 64 | Train Loss = 2.1903 | Val Loss = 2.8145
# Epoch 65 | Train Loss = 2.1435 | Val Loss = 2.6545
# Epoch 66 | Train Loss = 2.2069 | Val Loss = 2.7879
# Epoch 67 | Train Loss = 2.1565 | Val Loss = 2.6157
# Epoch 68 | Train Loss = 2.2047 | Val Loss = 2.8059
# Epoch 69 | Train Loss = 2.1206 | Val Loss = 2.6496
# Epoch 70 | Train Loss = 2.0818 | Val Loss = 2.5657
# Epoch 71 | Train Loss = 2.1342 | Val Loss = 2.7170
# Epoch 72 | Train Loss = 2.1242 | Val Loss = 2.6662
# Epoch 73 | Train Loss = 2.1039 | Val Loss = 2.5295
# Epoch 74 | Train Loss = 2.1648 | Val Loss = 2.5570
# Epoch 75 | Train Loss = 2.1220 | Val Loss = 2.5904
# Epoch 76 | Train Loss = 2.1046 | Val Loss = 2.5287
# Epoch 77 | Train Loss = 2.0285 | Val Loss = 2.6576
# Epoch 78 | Train Loss = 2.0748 | Val Loss = 2.6224
# Epoch 79 | Train Loss = 2.0474 | Val Loss = 2.4832
# Epoch 80 | Train Loss = 2.0201 | Val Loss = 2.8011
# Epoch 81 | Train Loss = 2.0352 | Val Loss = 2.3574
# Epoch 82 | Train Loss = 2.0027 | Val Loss = 2.4477
# Epoch 83 | Train Loss = 2.0687 | Val Loss = 2.3123
# Epoch 84 | Train Loss = 2.0175 | Val Loss = 2.3331
# Epoch 85 | Train Loss = 1.9724 | Val Loss = 2.4284
# Epoch 86 | Train Loss = 2.0418 | Val Loss = 2.2689
# Epoch 87 | Train Loss = 1.9670 | Val Loss = 2.4655
# Epoch 88 | Train Loss = 2.0127 | Val Loss = 2.2499
# Epoch 89 | Train Loss = 1.9506 | Val Loss = 2.3039
# Epoch 90 | Train Loss = 1.9829 | Val Loss = 2.2666
# Epoch 91 | Train Loss = 1.9937 | Val Loss = 2.9893
# Epoch 92 | Train Loss = 1.9562 | Val Loss = 2.1744
# Epoch 93 | Train Loss = 1.9237 | Val Loss = 2.2521
# Epoch 94 | Train Loss = 1.8767 | Val Loss = 2.4690
# Epoch 95 | Train Loss = 1.9535 | Val Loss = 2.1472
# Epoch 96 | Train Loss = 1.8571 | Val Loss = 2.3051
# Epoch 97 | Train Loss = 1.9075 | Val Loss = 2.0825
# Epoch 98 | Train Loss = 2.0018 | Val Loss = 2.6105
# Epoch 99 | Train Loss = 1.8443 | Val Loss = 2.1393
# Epoch 100 | Train Loss = 1.8583 | Val Loss = 2.0987
#
# Test Loss: 1.7409
#
# === Training GIN ===
# Epoch 01 | Train Loss = 3.4963 | Val Loss = 4.2332
# Epoch 02 | Train Loss = 3.1035 | Val Loss = 4.3312
# Epoch 03 | Train Loss = 2.9249 | Val Loss = 4.4507
# Epoch 04 | Train Loss = 3.0411 | Val Loss = 4.7084
# Epoch 05 | Train Loss = 2.9205 | Val Loss = 4.2050
# Epoch 06 | Train Loss = 2.9492 | Val Loss = 4.2168
# Epoch 07 | Train Loss = 2.8323 | Val Loss = 4.1434
# Epoch 08 | Train Loss = 2.7509 | Val Loss = 4.0146
# Epoch 09 | Train Loss = 2.7586 | Val Loss = 4.1656
# Epoch 10 | Train Loss = 2.7850 | Val Loss = 3.7718
# Epoch 11 | Train Loss = 2.5004 | Val Loss = 3.4700
# Epoch 12 | Train Loss = 2.3763 | Val Loss = 3.5817
# Epoch 13 | Train Loss = 2.3167 | Val Loss = 3.5243
# Epoch 14 | Train Loss = 2.3691 | Val Loss = 3.1270
# Epoch 15 | Train Loss = 2.1128 | Val Loss = 3.8863
# Epoch 16 | Train Loss = 2.4064 | Val Loss = 2.9986
# Epoch 17 | Train Loss = 2.1421 | Val Loss = 2.6394
# Epoch 18 | Train Loss = 2.1208 | Val Loss = 2.6213
# Epoch 19 | Train Loss = 1.8991 | Val Loss = 2.0457
# Epoch 20 | Train Loss = 1.8816 | Val Loss = 2.3422
# Epoch 21 | Train Loss = 1.8360 | Val Loss = 2.1060
# Epoch 22 | Train Loss = 1.6564 | Val Loss = 2.3264
# Epoch 23 | Train Loss = 1.6812 | Val Loss = 1.8234
# Epoch 24 | Train Loss = 1.6143 | Val Loss = 1.9087
# Epoch 25 | Train Loss = 1.8588 | Val Loss = 1.6161
# Epoch 26 | Train Loss = 1.6817 | Val Loss = 1.8562
# Epoch 27 | Train Loss = 1.5550 | Val Loss = 1.7257
# Epoch 28 | Train Loss = 1.7373 | Val Loss = 2.2339
# Epoch 29 | Train Loss = 1.5757 | Val Loss = 2.0566
# Epoch 30 | Train Loss = 1.5081 | Val Loss = 1.6154
# Epoch 31 | Train Loss = 1.4600 | Val Loss = 1.6289
# Epoch 32 | Train Loss = 1.4503 | Val Loss = 1.6567
# Epoch 33 | Train Loss = 1.5440 | Val Loss = 1.5585
# Epoch 34 | Train Loss = 1.5379 | Val Loss = 1.7133
# Epoch 35 | Train Loss = 1.6108 | Val Loss = 1.6425
# Epoch 36 | Train Loss = 1.4707 | Val Loss = 1.6007
# Epoch 37 | Train Loss = 1.4452 | Val Loss = 1.4496
# Epoch 38 | Train Loss = 1.3716 | Val Loss = 1.4653
# Epoch 39 | Train Loss = 1.3491 | Val Loss = 1.5305
# Epoch 40 | Train Loss = 1.3598 | Val Loss = 1.5003
# Epoch 41 | Train Loss = 1.3762 | Val Loss = 1.6789
# Epoch 42 | Train Loss = 1.3801 | Val Loss = 1.7541
# Epoch 43 | Train Loss = 1.4511 | Val Loss = 1.3158
# Epoch 44 | Train Loss = 1.5300 | Val Loss = 1.6013
# Epoch 45 | Train Loss = 1.3625 | Val Loss = 1.3606
# Epoch 46 | Train Loss = 1.3068 | Val Loss = 1.3732
# Epoch 47 | Train Loss = 1.2981 | Val Loss = 1.3162
# Epoch 48 | Train Loss = 1.3075 | Val Loss = 1.7324
# Epoch 49 | Train Loss = 1.5132 | Val Loss = 1.5374
# Epoch 50 | Train Loss = 1.2891 | Val Loss = 1.4155
# Epoch 51 | Train Loss = 1.3893 | Val Loss = 1.2181
# Epoch 52 | Train Loss = 1.3645 | Val Loss = 1.2493
# Epoch 53 | Train Loss = 1.2626 | Val Loss = 1.5866
# Epoch 54 | Train Loss = 1.2525 | Val Loss = 1.5344
# Epoch 55 | Train Loss = 1.2257 | Val Loss = 1.3836
# Epoch 56 | Train Loss = 1.3930 | Val Loss = 1.2876
# Epoch 57 | Train Loss = 1.4515 | Val Loss = 1.7832
# Epoch 58 | Train Loss = 1.4518 | Val Loss = 1.2137
# Epoch 59 | Train Loss = 1.2285 | Val Loss = 1.1987
# Epoch 60 | Train Loss = 1.2782 | Val Loss = 1.8152
# Epoch 61 | Train Loss = 1.2841 | Val Loss = 1.0977
# Epoch 62 | Train Loss = 1.2264 | Val Loss = 1.9971
# Epoch 63 | Train Loss = 1.3065 | Val Loss = 1.3065
# Epoch 64 | Train Loss = 1.3266 | Val Loss = 1.5814
# Epoch 65 | Train Loss = 1.2638 | Val Loss = 1.4430
# Epoch 66 | Train Loss = 1.1510 | Val Loss = 1.8836
# Epoch 67 | Train Loss = 1.2944 | Val Loss = 1.2063
# Epoch 68 | Train Loss = 1.3189 | Val Loss = 1.3799
# Epoch 69 | Train Loss = 1.2611 | Val Loss = 1.7661
# Epoch 70 | Train Loss = 1.2587 | Val Loss = 1.3014
# Epoch 71 | Train Loss = 1.2334 | Val Loss = 1.1942
# Epoch 72 | Train Loss = 1.1797 | Val Loss = 1.3270
# Epoch 73 | Train Loss = 1.1651 | Val Loss = 1.3742
# Epoch 74 | Train Loss = 1.1702 | Val Loss = 1.2936
# Epoch 75 | Train Loss = 1.2287 | Val Loss = 1.2479
# Epoch 76 | Train Loss = 1.1380 | Val Loss = 1.0918
# Epoch 77 | Train Loss = 1.2069 | Val Loss = 1.4477
# Epoch 78 | Train Loss = 1.1834 | Val Loss = 1.5998
# Epoch 79 | Train Loss = 1.5107 | Val Loss = 1.2139
# Epoch 80 | Train Loss = 1.3308 | Val Loss = 1.1648
# Epoch 81 | Train Loss = 1.1200 | Val Loss = 1.3169
# Epoch 82 | Train Loss = 1.2619 | Val Loss = 1.3350
# Epoch 83 | Train Loss = 1.1907 | Val Loss = 1.1537
# Epoch 84 | Train Loss = 1.0989 | Val Loss = 1.0770
# Epoch 85 | Train Loss = 1.1850 | Val Loss = 1.0610
# Epoch 86 | Train Loss = 1.1593 | Val Loss = 1.1075
# Epoch 87 | Train Loss = 1.1168 | Val Loss = 1.0296
# Epoch 88 | Train Loss = 1.1400 | Val Loss = 1.0007
# Epoch 89 | Train Loss = 1.1594 | Val Loss = 1.1089
# Epoch 90 | Train Loss = 1.0898 | Val Loss = 0.9976
# Epoch 91 | Train Loss = 1.1214 | Val Loss = 1.1233
# Epoch 92 | Train Loss = 1.0682 | Val Loss = 1.1566
# Epoch 93 | Train Loss = 1.0779 | Val Loss = 1.3743
# Epoch 94 | Train Loss = 1.2816 | Val Loss = 1.3865
# Epoch 95 | Train Loss = 1.4397 | Val Loss = 1.3909
# Epoch 96 | Train Loss = 1.0880 | Val Loss = 1.0206
# Epoch 97 | Train Loss = 1.0590 | Val Loss = 1.0894
# Epoch 98 | Train Loss = 1.0088 | Val Loss = 1.1671
# Epoch 99 | Train Loss = 1.0656 | Val Loss = 1.2712
# Epoch 100 | Train Loss = 1.0111 | Val Loss = 0.9724
#
# Test Loss: 1.2147
#
# === Training GAT ===
# Epoch 01 | Train Loss = 4.7750 | Val Loss = 4.9461
# Epoch 02 | Train Loss = 3.3437 | Val Loss = 4.9435
# Epoch 03 | Train Loss = 3.2903 | Val Loss = 4.9954
# Epoch 04 | Train Loss = 3.1967 | Val Loss = 4.7367
# Epoch 05 | Train Loss = 3.2557 | Val Loss = 4.7221
# Epoch 06 | Train Loss = 3.0142 | Val Loss = 4.4191
# Epoch 07 | Train Loss = 2.9881 | Val Loss = 4.2241
# Epoch 08 | Train Loss = 3.0138 | Val Loss = 4.0147
# Epoch 09 | Train Loss = 2.7521 | Val Loss = 3.8824
# Epoch 10 | Train Loss = 2.6614 | Val Loss = 3.7964
# Epoch 11 | Train Loss = 2.5572 | Val Loss = 3.5130
# Epoch 12 | Train Loss = 2.4175 | Val Loss = 3.1382
# Epoch 13 | Train Loss = 2.3663 | Val Loss = 3.0578
# Epoch 14 | Train Loss = 2.1669 | Val Loss = 2.8618
# Epoch 15 | Train Loss = 2.2089 | Val Loss = 3.0688
# Epoch 16 | Train Loss = 2.0252 | Val Loss = 2.5326
# Epoch 17 | Train Loss = 1.9615 | Val Loss = 2.0885
# Epoch 18 | Train Loss = 1.8826 | Val Loss = 2.3039
# Epoch 19 | Train Loss = 1.7857 | Val Loss = 1.9344
# Epoch 20 | Train Loss = 1.8073 | Val Loss = 1.9802
# Epoch 21 | Train Loss = 1.8009 | Val Loss = 1.8874
# Epoch 22 | Train Loss = 1.7410 | Val Loss = 1.7787
# Epoch 23 | Train Loss = 1.6953 | Val Loss = 1.8681
# Epoch 24 | Train Loss = 1.7051 | Val Loss = 1.9611
# Epoch 25 | Train Loss = 1.5964 | Val Loss = 1.6252
# Epoch 26 | Train Loss = 1.5799 | Val Loss = 1.4508
# Epoch 27 | Train Loss = 1.6471 | Val Loss = 1.4961
# Epoch 28 | Train Loss = 1.5545 | Val Loss = 1.4854
# Epoch 29 | Train Loss = 1.4169 | Val Loss = 1.5961
# Epoch 30 | Train Loss = 1.4928 | Val Loss = 1.3759
# Epoch 31 | Train Loss = 1.5220 | Val Loss = 1.3647
# Epoch 32 | Train Loss = 1.3733 | Val Loss = 2.0079
# Epoch 33 | Train Loss = 1.4153 | Val Loss = 1.9490
# Epoch 34 | Train Loss = 1.3643 | Val Loss = 1.3749
# Epoch 35 | Train Loss = 1.4132 | Val Loss = 1.4013
# Epoch 36 | Train Loss = 1.3721 | Val Loss = 1.3742
# Epoch 37 | Train Loss = 1.3423 | Val Loss = 1.1999
# Epoch 38 | Train Loss = 1.3080 | Val Loss = 1.2841
# Epoch 39 | Train Loss = 1.2721 | Val Loss = 1.3965
# Epoch 40 | Train Loss = 1.4244 | Val Loss = 1.3735
# Epoch 41 | Train Loss = 1.3936 | Val Loss = 1.2427
# Epoch 42 | Train Loss = 1.3930 | Val Loss = 1.1928
# Epoch 43 | Train Loss = 1.2229 | Val Loss = 1.3821
# Epoch 44 | Train Loss = 1.2401 | Val Loss = 1.4652
# Epoch 45 | Train Loss = 1.3504 | Val Loss = 1.6418
# Epoch 46 | Train Loss = 1.2371 | Val Loss = 1.5438
# Epoch 47 | Train Loss = 1.2549 | Val Loss = 1.2653
# Epoch 48 | Train Loss = 1.2070 | Val Loss = 1.3544
# Epoch 49 | Train Loss = 1.3459 | Val Loss = 1.1840
# Epoch 50 | Train Loss = 1.3670 | Val Loss = 1.1704
# Epoch 51 | Train Loss = 1.2451 | Val Loss = 1.1920
# Epoch 52 | Train Loss = 1.1878 | Val Loss = 1.5302
# Epoch 53 | Train Loss = 1.3089 | Val Loss = 1.1692
# Epoch 54 | Train Loss = 1.2401 | Val Loss = 1.6173
# Epoch 55 | Train Loss = 1.2396 | Val Loss = 1.1328
# Epoch 56 | Train Loss = 1.1587 | Val Loss = 1.1561
# Epoch 57 | Train Loss = 1.1193 | Val Loss = 1.0828
# Epoch 58 | Train Loss = 1.1178 | Val Loss = 1.4022
# Epoch 59 | Train Loss = 1.1679 | Val Loss = 1.1078
# Epoch 60 | Train Loss = 1.1815 | Val Loss = 1.7658
# Epoch 61 | Train Loss = 1.1624 | Val Loss = 1.2662
# Epoch 62 | Train Loss = 1.0989 | Val Loss = 1.1848
# Epoch 63 | Train Loss = 1.0872 | Val Loss = 1.0365
# Epoch 64 | Train Loss = 1.0533 | Val Loss = 0.9972
# Epoch 65 | Train Loss = 1.0595 | Val Loss = 1.4862
# Epoch 66 | Train Loss = 1.1146 | Val Loss = 1.1718
# Epoch 67 | Train Loss = 1.0507 | Val Loss = 1.0560
# Epoch 68 | Train Loss = 1.0061 | Val Loss = 0.9999
# Epoch 69 | Train Loss = 1.0336 | Val Loss = 0.9665
# Epoch 70 | Train Loss = 1.0686 | Val Loss = 0.9539
# Epoch 71 | Train Loss = 1.0680 | Val Loss = 1.3390
# Epoch 72 | Train Loss = 1.0858 | Val Loss = 1.0842
# Epoch 73 | Train Loss = 1.1193 | Val Loss = 1.2686
# Epoch 74 | Train Loss = 0.9797 | Val Loss = 1.0481
# Epoch 75 | Train Loss = 1.0224 | Val Loss = 1.1302
# Epoch 76 | Train Loss = 1.0674 | Val Loss = 1.0537
# Epoch 77 | Train Loss = 1.0074 | Val Loss = 0.9956
# Epoch 78 | Train Loss = 0.9697 | Val Loss = 1.0301
# Epoch 79 | Train Loss = 1.0612 | Val Loss = 1.2403
# Epoch 80 | Train Loss = 1.0182 | Val Loss = 1.1286
# Epoch 81 | Train Loss = 0.9779 | Val Loss = 1.0975
# Epoch 82 | Train Loss = 0.9444 | Val Loss = 1.0327
# Epoch 83 | Train Loss = 1.1712 | Val Loss = 0.9818
# Epoch 84 | Train Loss = 1.0155 | Val Loss = 0.9820
# Epoch 85 | Train Loss = 0.9713 | Val Loss = 1.0736
# Epoch 86 | Train Loss = 0.9544 | Val Loss = 1.1128
# Epoch 87 | Train Loss = 1.0162 | Val Loss = 0.9438
# Epoch 88 | Train Loss = 0.9677 | Val Loss = 1.2418
# Epoch 89 | Train Loss = 0.9796 | Val Loss = 0.9692
# Epoch 90 | Train Loss = 0.9451 | Val Loss = 1.4492
# Epoch 91 | Train Loss = 0.9246 | Val Loss = 1.1699
# Epoch 92 | Train Loss = 1.0707 | Val Loss = 1.0048
# Epoch 93 | Train Loss = 0.9723 | Val Loss = 0.9617
# Epoch 94 | Train Loss = 0.9409 | Val Loss = 1.3061
# Epoch 95 | Train Loss = 0.9018 | Val Loss = 0.8922
# Epoch 96 | Train Loss = 0.9238 | Val Loss = 1.0170
# Epoch 97 | Train Loss = 1.0834 | Val Loss = 0.9694
# Epoch 98 | Train Loss = 0.9958 | Val Loss = 0.9125
# Epoch 99 | Train Loss = 0.9611 | Val Loss = 0.9943
# Epoch 100 | Train Loss = 0.9179 | Val Loss = 1.2467
#
# Test Loss: 1.1645

# %%
import matplotlib.pyplot as plt
def parity_plot(model, test_loader, title="Parity Plot (Test Set)"):
    model.eval()
    preds = []
    trues = []

    with torch.no_grad():
        for batch in test_loader:
            pred = model(batch.x, batch.edge_index, batch.batch)

            # Ensure correct shapes
            pred = pred.view(-1).cpu()
            y = batch.y.view(-1).cpu()

            preds.append(pred)
            trues.append(y)

    preds = torch.cat(preds).numpy()
    trues = torch.cat(trues).numpy()

    # Parity plot
    plt.figure(figsize=(5,5))
    plt.scatter(trues, preds, alpha=0.6)
    plt.plot([trues.min(), trues.max()],
             [trues.min(), trues.max()],
             color='red', linestyle='--', linewidth=2)

    plt.xlabel("True logP")
    plt.ylabel("Predicted logP")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# Usage:

# %%
parity_plot(gcn, test_loader)

# %%
parity_plot(gin, test_loader)

# %%
parity_plot(gat, test_loader)
