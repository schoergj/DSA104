# %% [markdown]
# ### SMILES visualiser
#
# Use the cells below to visualise you SMILES strings. Simply paste them into the list in the last cell (Note: For minimalist reasons, the first cell could be nicely stored in a utils py-file.)

# %%
from rdkit import Chem
from rdkit.Chem import Draw

def visualise_smiles(smiles_list):
    mols_list=[]
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        mols_list.append(mol)
        if mol is None:
            print(f"Input {smiles} is not a valid SMILES!")

    img = Draw.MolsToGridImage(
        mols_list,
        subImgSize=(300,300)
    )
    
    return img

# %% [markdown]
# Place your input in the follwing cell and run it.

# %%
smiles_list = [
    "CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)[C@@H](C3=CC=C(C=C3)O)N)C(=O)O)C",
    "C1CN(CC1)C2=C(C=C3C(=C2)C(=O)C(=CN3C4CC4)C(=O)O)F",
    "CC[C@@H]1[C@@](C[C@@H]([C@H]([C@@H]([C@H](C(=O)O1)C)O[C@H]2C[C@@]([C@H]([C@@H](O2)C)O)(C)OC)C)O)(C)O[C@H]3[C@@H]([C@H]([C@@H]([C@H](O3)C)O)N(C)C)O",
    "CN(C)[C@@H]1C2=C(C[C@H]3C(=C(C4=C(C=CC=C4O)[C@@]3(C(=O)C2=C(C(=C1O)O)O)O)O)C(=O)N)O",
    "CC[C@H]1C(=O)N[C@@H](C2=C(C(=C(C=C2)Cl)O)C3=C(C=CC(=C3Cl)[C@H]4[C@@H](C(=O)N[C@](C(=O)N[C@H]5C(=O)N[C@]6(C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N1)C(C)C)C7=CC(=C(C=C7)O)O)C8=CC(=C(C=C8)O)O)CC9=CC(=C(C=C9)O)O)OC%10=CC(=CC(=C%10)OC1OC(C(C(C1O)O)OC1OC(C(C(C1O)O)O)CO)CO)C5)O)CC(=O)O)O",
    " C[C@ H ] 1 COc2c ( N3 C [ C @ H ] ( N ( C3 ) C ) c4cc ( F ) c ( cc4 C2 = O ) C ( = O ) O ) ccc1F"

]

visualise_smiles(smiles_list)
# Out:
# Input CC[C@H]1C(=O)N[C@@H](C2=C(C(=C(C=C2)Cl)O)C3=C(C=CC(=C3Cl)[C@H]4[C@@H](C(=O)N[C@](C(=O)N[C@H]5C(=O)N[C@]6(C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N1)C(C)C)C7=CC(=C(C=C7)O)O)C8=CC(=C(C=C8)O)O)CC9=CC(=C(C=C9)O)O)OC%10=CC(=CC(=C%10)OC1OC(C(C(C1O)O)OC1OC(C(C(C1O)O)O)CO)CO)C5)O)CC(=O)O)O is not a valid SMILES!
# Input  C[C@ H ] 1 COc2c ( N3 C [ C @ H ] ( N ( C3 ) C ) c4cc ( F ) c ( cc4 C2 = O ) C ( = O ) O ) ccc1F is not a valid SMILES!
# [09:29:50] SMILES Parse Error: unclosed ring for input: 'CC[C@H]1C(=O)N[C@@H](C2=C(C(=C(C=C2)Cl)O)C3=C(C=CC(=C3Cl)[C@H]4[C@@H](C(=O)N[C@](C(=O)N[C@H]5C(=O)N[C@]6(C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N1)C(C)C)C7=CC(=C(C=C7)O)O)C8=CC(=C(C=C8)O)O)CC9=CC(=C(C=C9)O)O)OC%10=CC(=CC(=C%10)OC1OC(C(C(C1O)O)OC1OC(C(C(C1O)O)O)CO)CO)C5)O)CC(=O)O)O'
# [09:29:50] SMILES Parse Error: syntax error while parsing: C[C@ H ] 1 COc2c ( N3 C [ C @ H ] ( N ( C3 ) C ) c4cc ( F ) c ( cc4 C2 = O ) C ( = O ) O ) ccc1F
# ...
